# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.42.69-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.43.0,>=1.42.69 (from boto3)
#   Downloading botocore-1.42.69-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.43.0,>=1.42.69->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.43.0,>=1.42.69->boto3) (2.0.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.69->boto3) (1.16.0)
# Downloading boto3-1.42.69-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 1.5 MB/s eta 0:00:00 0:00:01
# Downloading botocore-1.42.69-py3-none-any.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 7.8 MB/s eta 0:00:0000:0100:01
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.42.69 botocore-1.42.69 jmespath-1.1.0 s3transfer-0.16.0

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from datetime import time, datetime
import os
import boto3

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262,org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.0,org.apache.iceberg:iceberg-aws-bundle:1.5.0 pyspark-shell'

spark = SparkSession.builder \
    .appName('Iceberg Test') \
    .master('local[*]') \
    .config("spark.jars.packages", 
            "org.apache.hadoop:hadoop-aws:3.3.4,"
            "com.amazonaws:aws-java-sdk-bundle:1.12.262,"
            "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.0,"
            "org.apache.iceberg:iceberg-aws-bundle:1.5.0") \
    .config("spark.sql.extensions", 
            "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .config("spark.sql.catalog.iceberg", 
            "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.iceberg.type", "rest") \
    .config("spark.sql.catalog.iceberg.uri", "http://iceberg-rest:8181") \
    .config("spark.sql.catalog.iceberg.io-impl", "org.apache.iceberg.aws.s3.S3FileIO") \
    .config("spark.sql.catalog.iceberg.s3.endpoint", "http://minio:9000") \
    .config("spark.sql.catalog.iceberg.s3.access-key-id", "minioadmin") \
    .config("spark.sql.catalog.iceberg.s3.secret-access-key", "minioadmin") \
    .config("spark.sql.catalog.iceberg.s3.path-style-access", "true") \
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
    .config("spark.hadoop.fs.s3a.access.key", "minioadmin") \
    .config("spark.sql.catalog.iceberg.client.region", "us-east-1") \
    .config("spark.hadoop.fs.s3a.secret.key", "minioadmin") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .getOrCreate()

# %% [markdown]
# # Создание базы Apache Iceberg

# %%
spark.sql('CREATE DATABASE if not exists iceberg.silver')
# Out:
# DataFrame[]

# %%
#spark.sql('truncate table iceberg.silver.sales')

# %%
spark.sql("""
    CREATE TABLE IF NOT EXISTS iceberg.silver.sales (
        -- Основные колонки
        id                   STRING,
        period               STRING,
        retail_chain         STRING,
        category             STRING,
        category_2           STRING,
        supplier             STRING,
        brand                STRING,
        product_name         STRING,
        uni_product_name     STRING,
        grammage             STRING,
        flavor               STRING,
        sales_units          DOUBLE,
        sales_rub            DOUBLE,
        sales_tons           DOUBLE,
        cost_rub             DOUBLE,
        
        -- Служебные колонки
        year                 INT,
        month                INT,
        source_file          STRING,
        
        -- Новые колонки из декабря
        branch               STRING,
        region               STRING,
        city                 STRING,
        address              STRING,
        distribution_center  STRING,
        trade_point          STRING
    )
    USING iceberg
    PARTITIONED BY (retail_chain, year, month)
""")
# Out:
# DataFrame[]

# %% [markdown]
# # Считывание файлов с s3 и создание silver-слоя

# %%
s3 = boto3.client('s3', 
                  endpoint_url = 'http://minio:9000',
                  aws_access_key_id = 'minioadmin',
                  aws_secret_access_key = 'minioadmin')

# %%
SILVER_COLUMNS = {
    "id": "string",
    "period": "string",
    "retail_chain": "string",
    "category": "string",
    "category_2": "string",
    "supplier": "string",
    "brand": "string",
    "product_name": "string",
    "uni_product_name": "string",
    "grammage": "string",
    "flavor": "string",
    "sales_units": "double",
    "sales_rub": "double",
    "sales_tons": "double",
    "cost_rub": "double",
    "year": "int",
    "month": "int",
    "source_file": "string",
    "branch": "string",
    "region": "string",
    "city": "string",
    "address": "string",
    "distribution_center": "string",
    "trade_point": "string",
}

# ============================================================
# МАППИНГ: грязное имя → чистое имя
# ============================================================
COLUMN_MAPPING = {
    # ID
    "_c0": "id",
    
    # Период
    "Период": "period",
    "период": "period",
    "Period": "period",
    
    # Сеть
    "Сеть": "retail_chain",
    "Сеть ": "retail_chain",
    "сеть": "retail_chain",
    "Retail": "retail_chain",
    
    # Категории
    "Категория": "category",
    "категория": "category",
    "Category": "category",
    
    "Категория 2": "category_2",
    "категория 2": "category_2",
    "Category 2": "category_2",
    'Тип основы': 'category_2',
    
    # Поставщик
    "Поставщик": "supplier",
    "поставщик": "supplier",
    "Supplier": "supplier",
    "Поставщики": "supplier",
    
    # Бренд
    "Бренд": "brand",
    "Бренды": "brand",
    "бренд": "brand",
    "Brand": "brand",
    
    # Наименование
    "Наименование": "product_name",
    "наименование": "product_name",
    "Product": "product_name",
    
    # УНИ Наименование
    "УНИ Наименование": "uni_product_name",
    "уни наименование": "uni_product_name",
    "UNI Name": "uni_product_name",
    
    # Граммовка
    "Граммовка": "grammage",
    "граммовка": "grammage",
    "Grammage": "grammage",
    
    # Вкус / Вкусы → единое поле
    "Вкус": "flavor",
    "Вкусы": "flavor",
    "вкус": "flavor",
    "вкусы": "flavor",
    "Flavor": "flavor",
    
    # Продажи (с пробелами и без)
    "Продажи, шт": "sales_units",
    "Продажи, шт ": "sales_units",
    "продажи, шт": "sales_units",
    "Sales Units": "sales_units",
    
    "Продажи, руб": "sales_rub",
    "Продажи, руб ": "sales_rub",
    "продажи, руб": "sales_rub",
    "Sales RUB": "sales_rub",
    
    "Продажи, тонн": "sales_tons",
    "Продажи, тонн ": "sales_tons",
    "продажи, тонн": "sales_tons",
    "Sales Tons": "sales_tons",
    
    # Себестоимость
    "Себест., руб": "cost_rub",
    "Себест., руб ": "cost_rub",
    "себест., руб": "cost_rub",
    "Cost RUB": "cost_rub",
    'Себест. Руб': "cost_rub",

    "Филиал ": "branch",           
    "Регион": "region",            
    "Город ": "city",               
    "Адрес": "address",             
    "РЦ": "distribution_center",    
    "ТТ": "trade_point",            
}

# ============================================================
# МАППИНГ МЕСЯЦЕВ
# ============================================================
MONTH_MAPPING = {
    "january": 1, "february": 2, "march": 3,
    "april": 4, "may": 5, "june": 6,
    "july": 7, "august": 8, "september": 9,
    "ceptember": 9,
    "october": 10, "november": 11, "december": 12,
}

# %%
files = s3.list_objects(Bucket = 'data')['Contents']

for i in files:
    print(i['Key'])
    
    filename = 's3a://' + 'data/' + i['Key']

    print(f'Обрабатываем файл {filename}')
    
    df = spark.read.csv(filename, header = True)

    print(df.columns)

    for column in df.columns:

        new_col = COLUMN_MAPPING[column]
        new_dtype = SILVER_COLUMNS[new_col]

        df = df.withColumnRenamed(column, new_col)
        df = df.withColumn(new_col, col(new_col).cast(new_dtype))
        
        print(f'Колонка {column} преобразована в {new_col} с типом данных {SILVER_COLUMNS[new_col]}')

    print('Переименованные колонки:')
    print(df.printSchema())

    year_d = month_d = None
    
    if 'period' in df.columns:
        df = df.withColumn('period', to_date(col('period'), 'yyyy-MM-dd'))
        df = df.withColumn('year', year(col('period')).cast('int'))
        df = df.withColumn('month', month(col('period')).cast('int'))
    else:
        for part in filename.split('/'):
            if part.isdigit() and len(part) == 4:
                year_d = int(part)
            elif part.lower() in MONTH_MAPPING:
                month_d = MONTH_MAPPING[part.lower()]
        
        df = df.withColumn('year', lit(year_d).cast('int'))
        df = df.withColumn('month', lit(month_d).cast('int'))
            
        
    df = df.withColumn('source_file', lit(filename))
    
    print('Недостающие колонки')
    for col_rest in SILVER_COLUMNS:
        if col_rest not in df.columns:
            df = df.withColumn(col_rest, lit(None))

    print('Конечный (silver) вариант:')
    print(df.printSchema())
    

    #if spark.sql(f'SELECT COUNT(*) FROM iceberg.silver.sales where source_file = {filename}') != 
    
    df.writeTo('iceberg.silver.sales') \
    .using('iceberg') \
    .partitionedBy(col('retail_chain'), col('year'), col('month')) \
    .append()

    print('Данные занесены в табличку iceberg')
# Out:
# 2024/ceptember/okey
# Обрабатываем файл s3a://data/2024/ceptember/okey
# ['_c0', 'Период', 'Сеть', 'Категория', 'Категория 2', 'Поставщик', 'Бренд', 'Наименование', 'УНИ Наименование', 'Граммовка', 'Вкус', 'Продажи, шт', 'Продажи, руб', 'Продажи, тонн', 'Себест., руб']
# Колонка _c0 преобразована в id с типом данных string
# Колонка Период преобразована в period с типом данных string
# Колонка Сеть преобразована в retail_chain с типом данных string
# Колонка Категория преобразована в category с типом данных string
# Колонка Категория 2 преобразована в category_2 с типом данных string
# Колонка Поставщик преобразована в supplier с типом данных string
# Колонка Бренд преобразована в brand с типом данных string
# Колонка Наименование преобразована в product_name с типом данных string
# Колонка УНИ Наименование преобразована в uni_product_name с типом данных string
# Колонка Граммовка преобразована в grammage с типом данных string
# Колонка Вкус преобразована в flavor с типом данных string
# Колонка Продажи, шт преобразована в sales_units с типом данных double
# Колонка Продажи, руб преобразована в sales_rub с типом данных double
# Колонка Продажи, тонн преобразована в sales_tons с типом данных double
# Колонка Себест., руб преобразована в cost_rub с типом данных double
# Переименованные колонки:
# root
#  |-- id: string (nullable = true)
#  |-- period: string (nullable = true)
#  |-- retail_chain: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- category_2: string (nullable = true)
#  |-- supplier: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- uni_product_name: string (nullable = true)
#  |-- grammage: string (nullable = true)
#  |-- flavor: string (nullable = true)
#  |-- sales_units: double (nullable = true)
#  |-- sales_rub: double (nullable = true)
#  |-- sales_tons: double (nullable = true)
#  |-- cost_rub: double (nullable = true)
#
# None
# Недостающие колонки
# Конечный (silver) вариант:
# root
#  |-- id: string (nullable = true)
#  |-- period: date (nullable = true)
#  |-- retail_chain: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- category_2: string (nullable = true)
#  |-- supplier: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- uni_product_name: string (nullable = true)
#  |-- grammage: string (nullable = true)
#  |-- flavor: string (nullable = true)
#  |-- sales_units: double (nullable = true)
#  |-- sales_rub: double (nullable = true)
#  |-- sales_tons: double (nullable = true)
#  |-- cost_rub: double (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- source_file: string (nullable = false)
#  |-- branch: void (nullable = true)
#  |-- region: void (nullable = true)
#  |-- city: void (nullable = true)
#  |-- address: void (nullable = true)
#  |-- distribution_center: void (nullable = true)
#  |-- trade_point: void (nullable = true)
#
# None
# Данные занесены в табличку iceberg
# 2024/ceptember/perekrestok
# Обрабатываем файл s3a://data/2024/ceptember/perekrestok
# ['_c0', 'Период', 'Сеть', 'Категория', 'Категория 2', 'Поставщик', 'Бренд', 'Наименование', 'УНИ Наименование', 'Граммовка', 'Вкусы', 'Продажи, шт ', 'Продажи, руб ', 'Продажи, тонн ', 'Себест., руб ']
# Колонка _c0 преобразована в id с типом данных string
# Колонка Период преобразована в period с типом данных string
# Колонка Сеть преобразована в retail_chain с типом данных string
# Колонка Категория преобразована в category с типом данных string
# Колонка Категория 2 преобразована в category_2 с типом данных string
# Колонка Поставщик преобразована в supplier с типом данных string
# Колонка Бренд преобразована в brand с типом данных string
# Колонка Наименование преобразована в product_name с типом данных string
# Колонка УНИ Наименование преобразована в uni_product_name с типом данных string
# Колонка Граммовка преобразована в grammage с типом данных string
# Колонка Вкусы преобразована в flavor с типом данных string
# Колонка Продажи, шт  преобразована в sales_units с типом данных double
# Колонка Продажи, руб  преобразована в sales_rub с типом данных double
# Колонка Продажи, тонн  преобразована в sales_tons с типом данных double
# Колонка Себест., руб  преобразована в cost_rub с типом данных double
# Переименованные колонки:
# root
#  |-- id: string (nullable = true)
#  |-- period: string (nullable = true)
#  |-- retail_chain: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- category_2: string (nullable = true)
#  |-- supplier: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- uni_product_name: string (nullable = true)
#  |-- grammage: string (nullable = true)
#  |-- flavor: string (nullable = true)
#  |-- sales_units: double (nullable = true)
#  |-- sales_rub: double (nullable = true)
#  |-- sales_tons: double (nullable = true)
#  |-- cost_rub: double (nullable = true)
#
# None
# Недостающие колонки
# Конечный (silver) вариант:
# root
#  |-- id: string (nullable = true)
#  |-- period: date (nullable = true)
#  |-- retail_chain: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- category_2: string (nullable = true)
#  |-- supplier: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- uni_product_name: string (nullable = true)
#  |-- grammage: string (nullable = true)
#  |-- flavor: string (nullable = true)
#  |-- sales_units: double (nullable = true)
#  |-- sales_rub: double (nullable = true)
#  |-- sales_tons: double (nullable = true)
#  |-- cost_rub: double (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- source_file: string (nullable = false)
#  |-- branch: void (nullable = true)
#  |-- region: void (nullable = true)
#  |-- city: void (nullable = true)
#  |-- address: void (nullable = true)
#  |-- distribution_center: void (nullable = true)
#  |-- trade_point: void (nullable = true)
#
# None
# Данные занесены в табличку iceberg
# 2024/ceptember/pyaterochka
# Обрабатываем файл s3a://data/2024/ceptember/pyaterochka
# ['_c0', 'Период', 'Сеть', 'Категория', 'Тип основы', 'Поставщики', 'Бренды', 'Наименование', 'УНИ Наименование', 'Граммовка', 'Вкусы', 'Продажи, шт', 'Продажи, руб ', 'Продажи, тонн ', 'Себест., руб ']
# Колонка _c0 преобразована в id с типом данных string
# Колонка Период преобразована в period с типом данных string
# Колонка Сеть преобразована в retail_chain с типом данных string
# Колонка Категория преобразована в category с типом данных string
# Колонка Тип основы преобразована в category_2 с типом данных string
# Колонка Поставщики преобразована в supplier с типом данных string
# Колонка Бренды преобразована в brand с типом данных string
# Колонка Наименование преобразована в product_name с типом данных string
# Колонка УНИ Наименование преобразована в uni_product_name с типом данных string
# Колонка Граммовка преобразована в grammage с типом данных string
# Колонка Вкусы преобразована в flavor с типом данных string
# Колонка Продажи, шт преобразована в sales_units с типом данных double
# Колонка Продажи, руб  преобразована в sales_rub с типом данных double
# Колонка Продажи, тонн  преобразована в sales_tons с типом данных double
# Колонка Себест., руб  преобразована в cost_rub с типом данных double
# Переименованные колонки:
# root
#  |-- id: string (nullable = true)
#  |-- period: string (nullable = true)
#  |-- retail_chain: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- category_2: string (nullable = true)
#  |-- supplier: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- uni_product_name: string (nullable = true)
#  |-- grammage: string (nullable = true)
#  |-- flavor: string (nullable = true)
#  |-- sales_units: double (nullable = true)
#  |-- sales_rub: double (nullable = true)
#  |-- sales_tons: double (nullable = true)
#  |-- cost_rub: double (nullable = true)
#
# None
# Недостающие колонки
# Конечный (silver) вариант:
# root
#  |-- id: string (nullable = true)
#  |-- period: date (nullable = true)
#  |-- retail_chain: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- category_2: string (nullable = true)
#  |-- supplier: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- uni_product_name: string (nullable = true)
#  |-- grammage: string (nullable = true)
#  |-- flavor: string (nullable = true)
#  |-- sales_units: double (nullable = true)
#  |-- sales_rub: double (nullable = true)
#  |-- sales_tons: double (nullable = true)
#  |-- cost_rub: double (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- source_file: string (nullable = false)
#  |-- branch: void (nullable = true)
#  |-- region: void (nullable = true)
#  |-- city: void (nullable = true)
#  |-- address: void (nullable = true)
#  |-- distribution_center: void (nullable = true)
#  |-- trade_point: void (nullable = true)
#
# None
# Данные занесены в табличку iceberg
# 2024/december/perekrestok
# Обрабатываем файл s3a://data/2024/december/perekrestok
# ['_c0', 'Филиал ', 'Регион', 'Город ', 'Адрес', 'РЦ', 'Сеть ', 'Категория', 'Тип основы', 'Поставщик', 'Бренд', 'УНИ Наименование', 'Наименование', 'Граммовка', 'Вкус', 'Продажи, шт', 'Продажи, руб', 'Продажи, тонн', 'Себест. Руб', 'ТТ']
# Колонка _c0 преобразована в id с типом данных string
# Колонка Филиал  преобразована в branch с типом данных string
# Колонка Регион преобразована в region с типом данных string
# Колонка Город  преобразована в city с типом данных string
# Колонка Адрес преобразована в address с типом данных string
# Колонка РЦ преобразована в distribution_center с типом данных string
# Колонка Сеть  преобразована в retail_chain с типом данных string
# Колонка Категория преобразована в category с типом данных string
# Колонка Тип основы преобразована в category_2 с типом данных string
# Колонка Поставщик преобразована в supplier с типом данных string
# Колонка Бренд преобразована в brand с типом данных string
# Колонка УНИ Наименование преобразована в uni_product_name с типом данных string
# Колонка Наименование преобразована в product_name с типом данных string
# Колонка Граммовка преобразована в grammage с типом данных string
# Колонка Вкус преобразована в flavor с типом данных string
# Колонка Продажи, шт преобразована в sales_units с типом данных double
# Колонка Продажи, руб преобразована в sales_rub с типом данных double
# Колонка Продажи, тонн преобразована в sales_tons с типом данных double
# Колонка Себест. Руб преобразована в cost_rub с типом данных double
# Колонка ТТ преобразована в trade_point с типом данных string
# Переименованные колонки:
# root
#  |-- id: string (nullable = true)
#  |-- branch: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- distribution_center: string (nullable = true)
#  |-- retail_chain: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- category_2: string (nullable = true)
#  |-- supplier: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- uni_product_name: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- grammage: string (nullable = true)
#  |-- flavor: string (nullable = true)
#  |-- sales_units: double (nullable = true)
#  |-- sales_rub: double (nullable = true)
#  |-- sales_tons: double (nullable = true)
#  |-- cost_rub: double (nullable = true)
#  |-- trade_point: string (nullable = true)
#
# None
# Недостающие колонки
# Конечный (silver) вариант:
# root
#  |-- id: string (nullable = true)
#  |-- branch: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- distribution_center: string (nullable = true)
#  |-- retail_chain: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- category_2: string (nullable = true)
#  |-- supplier: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- uni_product_name: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- grammage: string (nullable = true)
#  |-- flavor: string (nullable = true)
#  |-- sales_units: double (nullable = true)
#  |-- sales_rub: double (nullable = true)
#  |-- sales_tons: double (nullable = true)
#  |-- cost_rub: double (nullable = true)
#  |-- trade_point: string (nullable = true)
#  |-- year: integer (nullable = false)
#  |-- month: integer (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- period: void (nullable = true)
#
# None
# Данные занесены в табличку iceberg

# %% [markdown]
# # Запросы к Apache Iceberg

# %%
spark.sql('SHOW TABLES in iceberg.silver').show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |   silver|    sales|      false|
# +---------+---------+-----------+

# %%
spark.sql('SELECT * FROM iceberg.silver.sales limit 10').show()
# Out:
# +---+----------+------------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------+--------------------+-----------+------------------+--------------------+------------------+----+-----+--------------------+------+------+----+-------+-------------------+-----------+
# | id|    period|retail_chain|            category| category_2|            supplier|               brand|        product_name|    uni_product_name|grammage|              flavor|sales_units|         sales_rub|          sales_tons|          cost_rub|year|month|         source_file|branch|region|city|address|distribution_center|trade_point|
# +---+----------+------------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------+--------------------+-----------+------------------+--------------------+------------------+----+-----+--------------------+------+------+----+-------+-------------------+-----------+
# |  0|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|"АО ""ТРАНСАТЛАНТ...|        Savoursmiths|SAVOUR.Чип.кар.вк...|Savoursmiths Итал...|     150|    Сыр и порто руби|      208.0|  99426.6400000001| 0.03120000000000008| 58307.63999999994|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# |  1|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|"АО ""ТРАНСАТЛАНТ...|        Savoursmiths|SAVOUR.Чип.карт.с...|Savoursmiths Сыр....|     150|     Сыр и лук-шалот|      225.0|105909.55000000009|0.033750000000000065| 62916.05999999997|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# |  2|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|"АО ""ТРАНСАТЛАНТ...|        Savoursmiths|SAVOURSM.Чипсы ка...|Savoursmiths Соль...|     150|                Соль|       84.0| 37699.30000000002|0.012600000000000012|23510.027999999995|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# |  3|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|Seykar gida san. ...|              PATTES|PATTES Чипсы КЛАС...|PATTES Оригинальн...|     100|        Оригинальные|       75.0|12236.779999999995|0.007500000000000...| 7181.699999999997|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# |  4|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|Seykar gida san. ...|              PATTES|PATTES Чипсы со в...|PATTES Йогурт и т...|     100|      Йогурт и травы|        6.0|            865.33|6.000000000000001E-4|             604.8|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# |  5|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|Seykar gida san. ...|              PATTES|PATTES Чипсы со в...|PATTES Красный пе...|     100|       Перец красный|        5.0|            949.35|              5.0E-4|            475.98|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# |  6|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|      Белпродукт ООО|Бульба картошечка...|БУЛЬБА Чип.CHIPS ...|Бульба картошечка...|     150|Утка и соус брусн...|       22.0|            2476.1|              0.0033|1526.7000000000003|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# |  7|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|      Белпродукт ООО|Бульба картошечка...|БУЛЬБА Чипсы сыр....|Бульба картошечка...|     150| Соль и перец черный|       19.0|1891.8000000000002|             0.00285|1319.0040000000001|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# |  8|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|      Белпродукт ООО|Бульба картошечка...|БУЛЬБА Чипсы сыр....|Бульба картошечка...|     150|             Трюфель|        5.0|354.28999999999996|              7.5E-4|347.03999999999996|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# |  9|2024-09-01| Перекрёсток|Чипсы картофельны...|ЧСК обычные|     Бумажная бумага|          EASY PEASY|EASY PEASY Картоф...| EASY PEASY Краб 50г|      50|                Краб|        1.0|              58.0|              5.0E-5|             37.26|2024|    9|s3a://data/2024/c...|  NULL|  NULL|NULL|   NULL|               NULL|       NULL|
# +---+----------+------------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------+--------------------+-----------+------------------+--------------------+------------------+----+-----+--------------------+------+------+----+-------+-------------------+-----------+

# %%
spark.sql('SELECT DISTINCT retail_chain from iceberg.silver.sales').show()
# Out:
# +-------------+
# | retail_chain|
# +-------------+
# |  Перекрёсток|
# |         Окей|
# |    Пятёрочка|
# |Перекресток04|
# +-------------+
