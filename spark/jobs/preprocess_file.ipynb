# %%
# !pip install -q findspark pyspark==3.5.3
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName('spark_transformation') \
    .master('local') \
    .getOrCreate()

spark
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 spark = SparkSession.builder \
#       2     .appName('spark_transformation') \
#       3     .master('local') \
# ----> 4     .getOrCreate()
#       6 spark
#
# File c:\Users\Smart\PycharmProjects\Data_analysis\.venv\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# File c:\Users\Smart\PycharmProjects\Data_analysis\.venv\Lib\site-packages\pyspark\context.py:515, in SparkContext.getOrCreate(cls, conf)
#     513 with SparkContext._lock:
# ...

# %%
import pandas as pd

# %%
df = pd.read_parquet('C:\\Users\\Smart\\PycharmProjects\\Data_analysis\\DE_Kaftal_improvement\\data\\00000-113-8c62399f-109a-4ef4-a300-ef4f2c556059-0-00001.parquet')

df
# Out:
#             id period   retail_chain                    category  \
# 0            0   None  Перекресток04          Чипсы прессованные
# 1            1   None  Перекресток04  Чипсы картофельные обычные
# 2            2   None  Перекресток04  Чипсы картофельные обычные
# 3            3   None  Перекресток04  Чипсы картофельные обычные
# 4            4   None  Перекресток04          Чипсы прессованные
# ...        ...    ...            ...                         ...
# 127578  127578   None  Перекресток04            Чипсы кукурузные
# 127579  127579   None  Перекресток04                Чипсы прочие
# 127580  127580   None  Перекресток04                Чипсы прочие
# 127581  127581   None  Перекресток04                Чипсы прочие
# 127582  127582   None  Перекресток04                Чипсы прочие
#
#                    category_2                  supplier          brand  \
# 0       Прессованные рифленые                 Фрито Лэй   Лейз из печи
# ...
