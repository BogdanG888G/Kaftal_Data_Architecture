# %%
from trino.dbapi import connect
from sqlalchemy import create_engine
import pandas as pd

# %%
conn = create_engine('trino://admin@localhost:8085')

df = pd.read_sql('SHOW CATALOGS', con = conn)
df_1 = pd.read_sql('SHOW TABLES IN clickhouse', con = conn)
# Out:
# ---------------------------------------------------------------------------
# TrinoUserError                            Traceback (most recent call last)
# File c:\Users\Smart\PycharmProjects\Data_analysis\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File c:\Users\Smart\PycharmProjects\Data_analysis\.venv\Lib\site-packages\trino\sqlalchemy\dialect.py:442, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     439 def do_execute(
#     440     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     441 ):
# --> 442     cursor.execute(statement, parameters)
#
# ...
